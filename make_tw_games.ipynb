# %%
# !pip install textworld
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 KB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.3/321.3 KB 11.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# Documentation: https://textworld.readthedocs.io/en/stable/tw-make.html

# %% [markdown]
# # tw-simple games

# %%
# !tw-make tw-simple --rewards dense    --goal detailed --seed 66 --test --silent -f --output tw_games/tw-rewardsDense_goalDetailed.z8
# !tw-make tw-simple --rewards balanced --goal detailed --seed 66 --test --silent -f --output tw_games/tw-rewardsBalanced_goalDetailed.z8
# !tw-make tw-simple --rewards sparse   --goal detailed --seed 66 --test --silent -f --output tw_games/tw-rewardsSparse_goalDetailed.z8
# !tw-make tw-simple --rewards dense    --goal brief    --seed 66 --test --silent -f --output tw_games/tw-rewardsDense_goalBrief.z8
# !tw-make tw-simple --rewards balanced --goal brief    --seed 66 --test --silent -f --output tw_games/tw-rewardsBalanced_goalBrief.z8
# !tw-make tw-simple --rewards sparse   --goal brief    --seed 66 --test --silent -f --output tw_games/tw-rewardsSparse_goalBrief.z8
# !tw-make tw-simple --rewards dense    --goal none     --seed 66 --test --silent -f --output tw_games/tw-rewardsDense_goalNone.z8
# !tw-make tw-simple --rewards balanced --goal none     --seed 66 --test --silent -f --output tw_games/tw-rewardsBalanced_goalNone.z8
# !tw-make tw-simple --rewards sparse   --goal none     --seed 66 --test --silent -f --output tw_games/tw-rewardsSparse_goalNone.z8

# %% [markdown]
# ### Generate 100 tw-simple training games with dense rewards and detailed goal

# %%
! seq 1 100 | xargs -n1 -P4 tw-make tw-simple --rewards dense --goal detailed --format z8 --output tw-simple_games/ --seed

# %% [markdown]
# # tw-coin_collector games

# %%
for i in range(1,301):
    # !tw-make tw-coin_collector --level {i} --seed 66 --output tw-coin_collector_games/tw-coin_collector_level-{i}.z8
# Out:
# Global seed: 66
# Game generated: /content/tw-games/tw-coin_collector_level-1.z8
# Global seed: 66
# Game generated: /content/tw-games/tw-coin_collector_level-2.z8
# Global seed: 66
# Game generated: /content/tw-games/tw-coin_collector_level-3.z8

# %% [markdown]
# # tw-treasure_hunter games

# %%
for i in range(1,31):
    # !tw-make tw-treasure_hunter --level {i} --seed 66 --output tw-treasure_hunter_games/tw-treasure_hunter_level-{i}.z8

# %% [markdown]
# # tw-cooking games

# %% [markdown]
# Recipe(INT): Number of ingredients in the recipe.
#
# Take(INT): Number of ingredients to find. (<= recipe)
#
# Go(INT): Number of locations in the game. (1, 6, 9, or 12)
#
# open/cook/cut/drop: T/F (Default: F)
#
# recipe-seed: Random seed used for generating the recipe.(Default: 0)

# %%
# !tw-make tw-cooking --recipe 1 --take 1 --go 1 --open --cook --cut --drop --recipe-seed 1 --seed 66 --output tw-cooking_games/tw-cooking_Recipe-1_Take-1_Go-1.z8
# Out:
# Global seed: 66
# Game generated: /content/tw-games/tw-cooking_Recipe-1_Take-1_Go-1.z8
